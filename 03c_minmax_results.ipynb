# %% [markdown]
# # Range of values across region types
#
# This notebook finds the minimum and maximum value of each category across all of the different region types.
#
# These min and max values will be used to estimate the colour limits needed to usefully display the data on a map.

# %%
import os
import pandas as pd

# %%
region_types = [
    'LSOA',
    'closest_ivt_unit',
    'closest_mt_unit',
    'closest_mt_transfer',
    # 'rural_urban_2011',
    'ambulance_service',
    # 'LAD22NM',
    # 'icb_code',
    'isdn',
    # 'lhb',
    'icb_lhb'
]

# %%
df_lsoa = pd.read_csv(f'data/collated_data_by_region/collated_data_regional_LSOA.csv', index_col=0)
df_ivt = pd.read_csv(f'data/collated_data_by_region/collated_data_regional_closest_ivt_unit.csv', index_col=0)
df_mt = pd.read_csv(f'data/collated_data_by_region/collated_data_regional_closest_mt_unit.csv', index_col=0)
df_transfer = pd.read_csv(f'data/collated_data_by_region/collated_data_regional_closest_mt_transfer.csv', index_col=0)
df_ambo = pd.read_csv(f'data/collated_data_by_region/collated_data_regional_ambulance_service.csv', index_col=0)
df_isdn = pd.read_csv(f'data/collated_data_by_region/collated_data_regional_isdn.csv', index_col=0)
df_icb_lhb = pd.read_csv(f'data/collated_data_by_region/collated_data_regional_icb_lhb.csv', index_col=0)

df_dict = {
    'LSOA': df_lsoa,
    'closest_ivt_unit': df_ivt,
    'closest_mt_unit': df_mt,
    'closest_mt_transfer': df_transfer,
    'ambulance_service': df_ambo,
    'isdn': df_isdn,
    'icb_lhb': df_icb_lhb
}

# %%
cols = df_lsoa.columns

cols
# Out:
# Index(['polygon_area_km2', 'population_all_x', 'population_density',
#        'income_domain_weighted_mean', 'imd_weighted_mean', 'weighted_ivt_time',
#        'mt_time_weighted_mean', 'ivt_time_weighted_mean',
#        'mt_transfer_time_weighted_mean',
#        'ethnic_group_other_than_white_british',
#        'ethnic_group_all_categories_ethnic_group',
#        'ethnic_minority_proportion', 'bad_or_very_bad_health',
#        'all_categories_general_health', 'bad_health_proportion',
#        'long_term_health_count',
#        'all_categories_long_term_health_problem_or_disability',
#        'long_term_health_proportion', 'age_65_plus_count', 'population_all_y',
#        'age_65_plus_proportion', 'ural_False', 'ural_True', 'proportion_rural',
#        'ver_65_within_30_False', 'ver_65_within_30_True',
#        'proportion_over_65_within_30', 'closest_is_m_False',
#        'closest_is_m_True', 'proportion_closest_is_mt'],
#       dtype='object')

# %%
# List of lists of columns:
all_cols = [df.columns.values.tolist() for df in list(df_dict.values())]
# Join into a single list:
all_cols = sum(all_cols, [])
# Remove duplicates:
all_cols = sorted(list(set(all_cols)))

# %%
all_cols
# Out:
# ['admissions_2122',
#  'age_65_plus_count',
#  'age_65_plus_proportion',
#  'all_categories_general_health',
#  'all_categories_long_term_health_problem_or_disability',
#  'bad_health_proportion',
#  'bad_or_very_bad_health',
#  'closest_is_m_False',
#  'closest_is_m_True',
#  'ethnic_group_all_categories_ethnic_group',
#  'ethnic_group_other_than_white_british',
#  'ethnic_minority_proportion',
#  'imd_weighted_mean',
#  'income_domain_weighted_mean',
#  'ivt_rate',
#  'ivt_time_weighted_mean',
#  'long_term_health_count',
#  'long_term_health_proportion',
#  'mt_time_weighted_mean',
#  'mt_transfer_time_weighted_mean',
#  'polygon_area_km2',
#  'population_all_x',
#  'population_all_y',
#  'population_density',
#  'proportion_closest_is_mt',
#  'proportion_over_65_within_30',
#  'proportion_rural',
#  'ural_False',
#  'ural_True',
#  'ver_65_within_30_False',
#  'ver_65_within_30_True',
#  'weighted_ivt_time']

# %%
# Check that all of these are numeric.
# Pull out the numeric column names...
cols_numeric = df_ivt.select_dtypes(include=['int64', 'float64'])
# ... and make sure the difference in sets of names is empty:
set(all_cols) - set(cols_numeric)

# %%
results_cols = []
for key in list(df_dict.keys()):
    results_cols += [f'{key}_min', f'{key}_max']

# %%
df_results = pd.DataFrame(index=all_cols, columns=results_cols)

for col in all_cols:
    for df_name, df in df_dict.items():
        try:
            min_here = df[col].min()
            max_here = df[col].max()
            df_results.at[col, f'{df_name}_min'] = min_here
            df_results.at[col, f'{df_name}_max'] = max_here
        except KeyError:
            pass

# %%
df_results
# Out:
#                                                    LSOA_min    LSOA_max  \
# admissions_2122                                         NaN         NaN
# age_65_plus_count                                         8        1215
# age_65_plus_proportion                               0.0013      0.6239
# all_categories_general_health                           983        8300
# all_categories_long_term_health_problem_or_disa...      613        3855
# bad_health_proportion                                0.0029      0.2351
# bad_or_very_bad_health                                    4         406
# closest_is_m_False                                      0.0      8712.0
# closest_is_m_True                                       0.0     17274.0
# ethnic_group_all_categories_ethnic_group                983        8300
# ethnic_group_other_than_white_british                     4        3234
# ethnic_minority_proportion                           0.0028      0.9937
# imd_weighted_mean                                       0.5      92.735
# income_domain_weighted_mean                           0.003       0.644
# ivt_rate                                                NaN         NaN
# ivt_time_weighted_mean                                  5.8        74.5
# long_term_health_count                                   24         850
# long_term_health_proportion                          0.0218      0.5521
# mt_time_weighted_mean                                   5.8       198.5
# mt_transfer_time_weighted_mean                          0.0       135.8
# polygon_area_km2                                     0.0435   2098.9715
# population_all_x                                        585       17274
# population_all_y                                        585       17274
# population_density                                   0.7751  41268.0671
# proportion_closest_is_mt                                0.0         1.0
# proportion_over_65_within_30                            0.0         1.0
# proportion_rural                                        0.0         1.0
# ural_False                                              0.0     17274.0
# ural_True                                               0.0      7400.0
# ver_65_within_30_False                                  0.0      1079.0
# ver_65_within_30_True                                   0.0      1215.0
# weighted_ivt_time                                       5.8        74.5
#
#                                                    closest_ivt_unit_min  \
# admissions_2122                                                     126
# age_65_plus_count                                                 22687
# age_65_plus_proportion                                           0.0824
# all_categories_general_health                                     89939
# all_categories_long_term_health_problem_or_disa...                85609
# bad_health_proportion                                            0.0321
# bad_or_very_bad_health                                             5258
# closest_is_m_False                                                  0.0
# closest_is_m_True                                                   0.0
# ethnic_group_all_categories_ethnic_group                          89939
# ethnic_group_other_than_white_british                              4249
# ethnic_minority_proportion                                       0.0312
# imd_weighted_mean                                                10.093
# income_domain_weighted_mean                                       0.058
# ivt_rate                                                            1.9
# ivt_time_weighted_mean                                          12.5913
# long_term_health_count                                            17845
# long_term_health_proportion                                       0.115
# mt_time_weighted_mean                                            14.389
# mt_transfer_time_weighted_mean                                      0.0
# polygon_area_km2                                               207.4601
# population_all_x                                                  87086
# population_all_y                                                  87086
# population_density                                               9.4821
# proportion_closest_is_mt                                            0.0
# proportion_over_65_within_30                                     0.3588
# proportion_rural                                                    0.0
# ural_False                                                      17335.0
# ural_True                                                           0.0
# ver_65_within_30_False                                              0.0
# ver_65_within_30_True                                            8141.0
# weighted_ivt_time                                               12.8909
#
#                                                    closest_ivt_unit_max  \
# admissions_2122                                                    1848
# age_65_plus_count                                                195054
# age_65_plus_proportion                                           0.2871
# all_categories_general_health                                   1288965
# all_categories_long_term_health_problem_or_disa...              1274799
# bad_health_proportion                                            0.1032
# bad_or_very_bad_health                                            73691
# closest_is_m_False                                            1383341.0
# closest_is_m_True                                             1479138.0
# ethnic_group_all_categories_ethnic_group                        1288965
# ethnic_group_other_than_white_british                            863615
# ethnic_minority_proportion                                        0.685
# imd_weighted_mean                                               36.6013
# income_domain_weighted_mean                                      0.2095
# ivt_rate                                                           27.5
# ivt_time_weighted_mean                                          32.5503
# long_term_health_count                                           201748
# long_term_health_proportion                                      0.2625
# mt_time_weighted_mean                                          168.3503
# mt_transfer_time_weighted_mean                                    135.8
# polygon_area_km2                                             13940.3174
# population_all_x                                                1479138
# population_all_y                                                1479138
# population_density                                             4023.385
# proportion_closest_is_mt                                            1.0
# proportion_over_65_within_30                                        1.0
# proportion_rural                                                 0.8384
# ural_False                                                    1479138.0
# ural_True                                                      248854.0
# ver_65_within_30_False                                          65122.0
# ver_65_within_30_True                                          191170.0
# weighted_ivt_time                                               35.5818
#
#                                                    closest_mt_unit_min  \
# admissions_2122                                                    NaN
# age_65_plus_count                                               107901
# age_65_plus_proportion                                          0.1023
# all_categories_general_health                                   936123
# all_categories_long_term_health_problem_or_disa...              925753
# bad_health_proportion                                           0.0364
# bad_or_very_bad_health                                           44645
# closest_is_m_False                                              187300
# closest_is_m_True                                               468512
# ethnic_group_all_categories_ethnic_group                        936123
# ethnic_group_other_than_white_british                            69597
# ethnic_minority_proportion                                      0.0512
# imd_weighted_mean                                              12.4094
# income_domain_weighted_mean                                     0.0758
# ivt_rate                                                           NaN
# ivt_time_weighted_mean                                         14.7997
# long_term_health_count                                          123735
# long_term_health_proportion                                     0.1257
# mt_time_weighted_mean                                          21.2083
# mt_transfer_time_weighted_mean                                  6.4086
# polygon_area_km2                                               334.216
# population_all_x                                               1017754
# population_all_y                                               1017754
# population_density                                             62.2216
# proportion_closest_is_mt                                        0.1661
# proportion_over_65_within_30                                    0.5065
# proportion_rural                                                   0.0
# ural_False                                                    816707.0
# ural_True                                                          0.0
# ver_65_within_30_False                                             0.0
# ver_65_within_30_True                                         107901.0
# weighted_ivt_time                                              15.0569
#
#                                                    closest_mt_unit_max  \
# admissions_2122                                                    NaN
# age_65_plus_count                                               910958
# age_65_plus_proportion                                          0.2467
# all_categories_general_health                                  4493628
# all_categories_long_term_health_problem_or_disa...             4432326
# bad_health_proportion                                           0.0806
# bad_or_very_bad_health                                          228235
# closest_is_m_False                                             3643885
# closest_is_m_True                                              1479138
# ethnic_group_all_categories_ethnic_group                       4493628
# ethnic_group_other_than_white_british                          1569876
# ethnic_minority_proportion                                      0.5715
# imd_weighted_mean                                              28.5709
# income_domain_weighted_mean                                     0.1732
# ivt_rate                                                           NaN
# ivt_time_weighted_mean                                         29.2502
# long_term_health_count                                          733387
# long_term_health_proportion                                     0.2267
# mt_time_weighted_mean                                          75.6794
# mt_transfer_time_weighted_mean                                  53.179
# polygon_area_km2                                            39560.3278
# population_all_x                                               4858735
# population_all_y                                               4858735
# population_density                                           3045.1981
# proportion_closest_is_mt                                         0.816
# proportion_over_65_within_30                                       1.0
# proportion_rural                                                 0.428
# ural_False                                                   3990943.0
# ural_True                                                    1332409.0
# ver_65_within_30_False                                        174592.0
# ver_65_within_30_True                                         745300.0
# weighted_ivt_time                                              32.2293
#
#                                                    closest_mt_transfer_min  \
# admissions_2122                                                        NaN
# age_65_plus_count                                                   121918
# age_65_plus_proportion                                              0.0824
# all_categories_general_health                                       896382
# all_categories_long_term_health_problem_or_disa...                  882914
# bad_health_proportion                                               0.0367
# bad_or_very_bad_health                                               54915
# closest_is_m_False                                                     0.0
# closest_is_m_True                                                 468512.0
# ethnic_group_all_categories_ethnic_group                            896382
# ethnic_group_other_than_white_british                                57581
# ethnic_minority_proportion                                          0.0516
# imd_weighted_mean                                                  13.1838
# income_domain_weighted_mean                                          0.081
# ivt_rate                                                               NaN
# ivt_time_weighted_mean                                             15.3983
# long_term_health_count                                              166504
# long_term_health_proportion                                         0.1236
# mt_time_weighted_mean                                              15.3983
# mt_transfer_time_weighted_mean                                         0.0
# polygon_area_km2                                                  367.6352
# population_all_x                                                    911857
# population_all_y                                                    911857
# population_density                                                 66.8259
# proportion_closest_is_mt                                            0.1491
# proportion_over_65_within_30                                        0.6298
# proportion_rural                                                       0.0
# ural_False                                                        692472.0
# ural_True                                                              0.0
# ver_65_within_30_False                                                 0.0
# ver_65_within_30_True                                             121918.0
# weighted_ivt_time                                                  15.9919
#
#                                                    closest_mt_transfer_max  \
# admissions_2122                                                        NaN
# age_65_plus_count                                                   905940
# age_65_plus_proportion                                              0.2461
# all_categories_general_health                                      4560888
# all_categories_long_term_health_problem_or_disa...                 4500601
# bad_health_proportion                                               0.0813
# bad_or_very_bad_health                                              249691
# closest_is_m_False                                               3725660.0
# closest_is_m_True                                                1479138.0
# ethnic_group_all_categories_ethnic_group                           4560888
# ethnic_group_other_than_white_british                              1900023
# ethnic_minority_proportion                                           0.685
# imd_weighted_mean                                                  29.1704
# income_domain_weighted_mean                                         0.1725
# ivt_rate                                                               NaN
# ivt_time_weighted_mean                                             24.1239
# long_term_health_count                                              742782
# long_term_health_proportion                                         0.2281
# mt_time_weighted_mean                                              76.7368
# mt_transfer_time_weighted_mean                                     53.7038
# polygon_area_km2                                                46768.7995
# population_all_x                                                   4940510
# population_all_y                                                   4940510
# population_density                                                4023.385
# proportion_closest_is_mt                                               1.0
# proportion_over_65_within_30                                           1.0
# proportion_rural                                                    0.4223
# ural_False                                                       4108745.0
# ural_True                                                        1395924.0
# ver_65_within_30_False                                            216716.0
# ver_65_within_30_True                                             751683.0
# weighted_ivt_time                                                  26.1582
#
#                                                    ambulance_service_min  \
# admissions_2122                                                      NaN
# age_65_plus_count                                                  40858
# age_65_plus_proportion                                             0.122
# all_categories_general_health                                     138265
# all_categories_long_term_health_problem_or_disa...                133713
# bad_health_proportion                                             0.0393
# bad_or_very_bad_health                                              8953
# closest_is_m_False                                              142296.0
# closest_is_m_True                                                    0.0
# ethnic_group_all_categories_ethnic_group                          138265
# ethnic_group_other_than_white_british                               7166
# ethnic_minority_proportion                                        0.0518
# imd_weighted_mean                                                14.2671
# income_domain_weighted_mean                                       0.0827
# ivt_rate                                                             NaN
# ivt_time_weighted_mean                                           16.3042
# long_term_health_count                                             28739
# long_term_health_proportion                                       0.1381
# mt_time_weighted_mean                                            25.4505
# mt_transfer_time_weighted_mean                                    9.1464
# polygon_area_km2                                                946.2206
# population_all_x                                                  142296
# population_all_y                                                  142296
# population_density                                               57.0088
# proportion_closest_is_mt                                             0.0
# proportion_over_65_within_30                                      0.7695
# proportion_rural                                                  0.0014
# ural_False                                                         99633
# ural_True                                                          12558
# ver_65_within_30_False                                               0.0
# ver_65_within_30_True                                            40858.0
# weighted_ivt_time                                                16.5809
#
#                                                    ambulance_service_max  \
# admissions_2122                                                      NaN
# age_65_plus_count                                                1392786
# age_65_plus_proportion                                            0.2871
# all_categories_general_health                                    8173941
# all_categories_long_term_health_problem_or_disa...               8073700
# bad_health_proportion                                             0.0763
# bad_or_very_bad_health                                            480812
# closest_is_m_False                                             5433023.0
# closest_is_m_True                                              6141216.0
# ethnic_group_all_categories_ethnic_group                         8173941
# ethnic_group_other_than_white_british                            4504657
# ethnic_minority_proportion                                        0.5511
# imd_weighted_mean                                                28.2195
# income_domain_weighted_mean                                       0.1722
# ivt_rate                                                             NaN
# ivt_time_weighted_mean                                           21.6366
# long_term_health_count                                           1376430
# long_term_health_proportion                                       0.2229
# mt_time_weighted_mean                                           136.1055
# mt_transfer_time_weighted_mean                                     117.5
# polygon_area_km2                                              60222.2636
# population_all_x                                                 9002488
# population_all_y                                                 9002488
# population_density                                             2219.6519
# proportion_closest_is_mt                                          0.6822
# proportion_over_65_within_30                                         1.0
# proportion_rural                                                  0.3147
# ural_False                                                       8989930
# ural_True                                                        1806936
# ver_65_within_30_False                                          292976.0
# ver_65_within_30_True                                          1284258.0
# weighted_ivt_time                                                 22.831
#
#                                                      isdn_min    isdn_max  \
# admissions_2122                                           NaN         NaN
# age_65_plus_count                                    256086.0   1098453.0
# age_65_plus_proportion                                  0.122      0.2461
# all_categories_general_health                       1343601.0   8173941.0
# all_categories_long_term_health_problem_or_disa...  1321137.0   8073700.0
# bad_health_proportion                                  0.0343      0.0729
# bad_or_very_bad_health                                55320.0    405473.0
# closest_is_m_False                                   655973.0   3869052.0
# closest_is_m_True                                         0.0   6141216.0
# ethnic_group_all_categories_ethnic_group            1343601.0   8173941.0
# ethnic_group_other_than_white_british                 85372.0   4504657.0
# ethnic_minority_proportion                             0.0512      0.5511
# imd_weighted_mean                                     11.1617     30.3287
# income_domain_weighted_mean                            0.0684       0.174
# ivt_rate                                                  NaN         NaN
# ivt_time_weighted_mean                                16.3042     27.0176
# long_term_health_count                               203428.0   1115302.0
# long_term_health_proportion                            0.1272      0.2093
# mt_time_weighted_mean                                 25.4505     92.8356
# mt_transfer_time_weighted_mean                         9.1464      70.863
# polygon_area_km2                                    3604.5562  42950.6743
# population_all_x                                    1415054.0   9002488.0
# population_all_y                                    1415054.0   9002488.0
# population_density                                    55.3298   2219.6519
# proportion_closest_is_mt                                  0.0      0.6822
# proportion_over_65_within_30                           0.5571      0.9983
# proportion_rural                                       0.0014      0.4259
# ural_False                                          1023647.0   8989930.0
# ural_True                                             12558.0   1270455.0
# ver_65_within_30_False                                  427.0    182211.0
# ver_65_within_30_True                                210899.0   1083963.0
# weighted_ivt_time                                     16.5809       29.11
#
#                                                    icb_lhb_min icb_lhb_max
# admissions_2122                                            NaN         NaN
# age_65_plus_count                                        36801      614170
# age_65_plus_proportion                                  0.1031      0.2766
# all_categories_general_health                           132976     2914801
# all_categories_long_term_health_problem_or_disa...      131047     2864278
# bad_health_proportion                                   0.0343      0.0959
# bad_or_very_bad_health                                    8149      212456
# closest_is_m_False                                         0.0   2290213.0
# closest_is_m_True                                          0.0   2036470.0
# ethnic_group_all_categories_ethnic_group                132976     2914801
# ethnic_group_other_than_white_british                     5203     1283629
# ethnic_minority_proportion                              0.0391      0.6492
# imd_weighted_mean                                      10.3133     34.7949
# income_domain_weighted_mean                             0.0618      0.2036
# ivt_rate                                                   NaN         NaN
# ivt_time_weighted_mean                                 13.0956     44.1576
# long_term_health_count                                   27235      599458
# long_term_health_proportion                             0.1239      0.2515
# mt_time_weighted_mean                                  14.9539    110.7412
# mt_transfer_time_weighted_mean                             0.0     89.3946
# polygon_area_km2                                      609.2689  41176.1385
# population_all_x                                        133030     3000432
# population_all_y                                        133030     3000432
# population_density                                      9.5751   2505.5964
# proportion_closest_is_mt                                   0.0         1.0
# proportion_over_65_within_30                              0.13         1.0
# proportion_rural                                           0.0      0.8641
# ural_False                                             18085.0   2828436.0
# ural_True                                                  0.0    655322.0
# ver_65_within_30_False                                     0.0    167635.0
# ver_65_within_30_True                                   4784.0    525985.0
# weighted_ivt_time                                      13.3964     44.1326
